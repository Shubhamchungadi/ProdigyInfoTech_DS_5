# %% [markdown]
# ## Business Understanding

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter("ignore")

# %% [markdown]
# ## Dataset Understanding

# %%
data = pd.read_csv(r"D:\Data Science and AI\PYTHON\Prodigy Infotech\Prodigy task 5\RTA Dataset.csv")
data.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %%
data["Time"].unique
# Out:
# <bound method Series.unique of 0        17:02:00
# 1        17:02:00
# 2        17:02:00
# 3         1:06:00
# 4         1:06:00
#            ...
# 12311    16:15:00
# 12312    18:00:00
# 12313    13:55:00
# 12314    13:55:00
# 12315    13:55:00
# Name: Time, Length: 12316, dtype: object>

# %%
data["Time"].value_counts()
# Out:
# Time
# 15:30:00    120
# 17:10:00    110
# 18:30:00    103
# 11:30:00     99
# 17:00:00     98
#            ...
# 0:52:00       1
# 4:49:00       1
# 14:31:00      1
# 19:18:00      1
# 2:47:00       1
# Name: count, Length: 1074, dtype: int64

# %%
data["Day_of_week"].unique()          # Day's of week
# Out:
# array(['Monday', 'Sunday', 'Friday', 'Wednesday', 'Saturday', 'Thursday',
#        'Tuesday'], dtype=object)

# %%
data["Day_of_week"].value_counts()
# Out:
# Day_of_week
# Friday       2041
# Thursday     1851
# Wednesday    1840
# Tuesday      1770
# Monday       1681
# Saturday     1666
# Sunday       1467
# Name: count, dtype: int64

# %%
data["Age_band_of_driver"].unique()          # Age groups
# Out:
# array(['18-30', '31-50', 'Under 18', 'Over 51', 'Unknown'], dtype=object)

# %%
data["Age_band_of_driver"].value_counts()
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64

# %%
data["Sex_of_driver"].unique()          # Gender
# Out:
# array(['Male', 'Female', 'Unknown'], dtype=object)

# %%
data["Sex_of_driver"].value_counts()
# Out:
# Sex_of_driver
# Male       11437
# Female       701
# Unknown      178
# Name: count, dtype: int64

# %%
data["Educational_level"].unique()               # Qualification
# Out:
# array(['Above high school', 'Junior high school', nan,
#        'Elementary school', 'High school', 'Unknown', 'Illiterate',
#        'Writing & reading'], dtype=object)

# %%
data["Educational_level"].value_counts()
# Out:
# Educational_level
# Junior high school    7619
# Elementary school     2163
# High school           1110
# Above high school      362
# Writing & reading      176
# Unknown                100
# Illiterate              45
# Name: count, dtype: int64

# %%
data["Vehicle_driver_relation"].unique()       # Relation
# Out:
# array(['Employee', 'Unknown', 'Owner', nan, 'Other'], dtype=object)

# %%
data["Vehicle_driver_relation"].value_counts()
# Out:
# Vehicle_driver_relation
# Employee    9627
# Owner       1973
# Other        123
# Unknown       14
# Name: count, dtype: int64

# %%
data["Driving_experience"].unique()         # How much driving experience
# Out:
# array(['1-2yr', 'Above 10yr', '5-10yr', '2-5yr', nan, 'No Licence',
#        'Below 1yr', 'unknown'], dtype=object)

# %%
data["Driving_experience"].value_counts()
# Out:
# Driving_experience
# 5-10yr        3363
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: count, dtype: int64

# %%
data["Type_of_vehicle"].unique()              # Vehicle Type
# Out:
# array(['Automobile', 'Public (> 45 seats)', 'Lorry (41?100Q)', nan,
#        'Public (13?45 seats)', 'Lorry (11?40Q)', 'Long lorry',
#        'Public (12 seats)', 'Taxi', 'Pick up upto 10Q', 'Stationwagen',
#        'Ridden horse', 'Other', 'Bajaj', 'Turbo', 'Motorcycle',
#        'Special vehicle', 'Bicycle'], dtype=object)

# %%
data["Type_of_vehicle"].value_counts()
# Out:
# Type_of_vehicle
# Automobile              3205
# Lorry (41?100Q)         2186
# Other                   1208
# Pick up upto 10Q         811
# Public (12 seats)        711
# Stationwagen             687
# Lorry (11?40Q)           541
# Public (13?45 seats)     532
# Public (> 45 seats)      404
# Long lorry               383
# Taxi                     265
# Motorcycle               177
# Special vehicle           84
# Ridden horse              76
# Turbo                     46
# Bajaj                     29
# Bicycle                   21
# Name: count, dtype: int64

# %%
data["Owner_of_vehicle"].unique()                   # Vehicle Owner
# Out:
# array(['Owner', 'Governmental', nan, 'Organization', 'Other'],
#       dtype=object)

# %%
data["Owner_of_vehicle"].value_counts()
# Out:
# Owner_of_vehicle
# Owner           10459
# Governmental     1041
# Organization      312
# Other              22
# Name: count, dtype: int64

# %%
data["Service_year_of_vehicle"].unique()          # Service Year
# Out:
# array(['Above 10yr', '5-10yrs', nan, '1-2yr', '2-5yrs', 'Unknown',
#        'Below 1yr'], dtype=object)

# %%
data["Service_year_of_vehicle"].value_counts()
# Out:
# Service_year_of_vehicle
# Unknown       2883
# 2-5yrs        1792
# Above 10yr    1324
# 5-10yrs       1280
# 1-2yr          827
# Below 1yr      282
# Name: count, dtype: int64

# %%
data["Defect_of_vehicle"].unique()             # Defects
# Out:
# array(['No defect', nan, '7', '5'], dtype=object)

# %%
data["Defect_of_vehicle"].value_counts()
# Out:
# Defect_of_vehicle
# No defect    7777
# 7              76
# 5              36
# Name: count, dtype: int64

# %%
data["Area_accident_occured"].unique()             # Accidednt Area
# Out:
# array(['Residential areas', 'Office areas', '  Recreational areas',
#        ' Industrial areas', nan, 'Other', ' Church areas',
#        '  Market areas', 'Unknown', 'Rural village areas',
#        ' Outside rural areas', ' Hospital areas', 'School areas',
#        'Rural village areasOffice areas', 'Recreational areas'],
#       dtype=object)

# %%
data["Area_accident_occured"].value_counts()
# Out:
# Area_accident_occured
# Other                              3819
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
#  Industrial areas                   456
# School areas                        415
#   Recreational areas                327
#  Outside rural areas                218
#  Hospital areas                     121
#   Market areas                       63
# Rural village areas                  44
# Unknown                              22
# Rural village areasOffice areas      20
# Recreational areas                    1
# Name: count, dtype: int64

# %%
data["Lanes_or_Medians"].unique()
# Out:
# array([nan, 'Undivided Two way', 'other', 'Double carriageway (median)',
#        'One way', 'Two-way (divided with solid lines road marking)',
#        'Two-way (divided with broken lines road marking)', 'Unknown'],
#       dtype=object)

# %%
data["Lanes_or_Medians"].value_counts()
# Out:
# Lanes_or_Medians
# Two-way (divided with broken lines road marking)    4411
# Undivided Two way                                   3796
# other                                               1660
# Double carriageway (median)                         1020
# One way                                              845
# Two-way (divided with solid lines road marking)      142
# Unknown                                               57
# Name: count, dtype: int64

# %%
data["Road_allignment"].unique()
# Out:
# array(['Tangent road with flat terrain', nan,
#        'Tangent road with mild grade and flat terrain', 'Escarpments',
#        'Tangent road with rolling terrain', 'Gentle horizontal curve',
#        'Tangent road with mountainous terrain and',
#        'Steep grade downward with mountainous terrain',
#        'Sharp reverse curve',
#        'Steep grade upward with mountainous terrain'], dtype=object)

# %%
data["Road_allignment"].value_counts()
# Out:
# Road_allignment
# Tangent road with flat terrain                   10459
# Tangent road with mild grade and flat terrain      501
# Steep grade downward with mountainous terrain      429
# Tangent road with mountainous terrain and          396
# Gentle horizontal curve                            163
# Escarpments                                        113
# Sharp reverse curve                                 57
# Tangent road with rolling terrain                   37
# Steep grade upward with mountainous terrain         19
# Name: count, dtype: int64

# %%
data["Types_of_Junction"].unique()    # Types_of_Junction
# Out:
# array(['No junction', 'Y Shape', 'Crossing', 'O Shape', 'Other',
#        'Unknown', 'T Shape', 'X Shape', nan], dtype=object)

# %%
data["Types_of_Junction"].value_counts()
# Out:
# Types_of_Junction
# Y Shape        4543
# No junction    3837
# Crossing       2177
# Other           445
# Unknown         191
# O Shape         164
# T Shape          60
# X Shape          12
# Name: count, dtype: int64

# %%
data["Road_surface_type"].unique()               # Road Type
# Out:
# array(['Asphalt roads', 'Earth roads', nan,
#        'Asphalt roads with some distress', 'Gravel roads', 'Other'],
#       dtype=object)

# %%
data["Road_surface_type"].value_counts()
# Out:
# Road_surface_type
# Asphalt roads                       11296
# Earth roads                           358
# Gravel roads                          242
# Other                                 167
# Asphalt roads with some distress       81
# Name: count, dtype: int64

# %%
data["Road_surface_conditions"].unique()                   # Road Surface Condition
# Out:
# array(['Dry', 'Wet or damp', 'Snow', 'Flood over 3cm. deep'], dtype=object)

# %%
data["Road_surface_conditions"].value_counts()
# Out:
# Road_surface_conditions
# Dry                     9340
# Wet or damp             2904
# Snow                      70
# Flood over 3cm. deep       2
# Name: count, dtype: int64

# %%
data["Light_conditions"].unique()                     # Light
# Out:
# array(['Daylight', 'Darkness - lights lit', 'Darkness - no lighting',
#        'Darkness - lights unlit'], dtype=object)

# %%
data["Light_conditions"].value_counts()
# Out:
# Light_conditions
# Daylight                   8798
# Darkness - lights lit      3286
# Darkness - no lighting      192
# Darkness - lights unlit      40
# Name: count, dtype: int64

# %%
data["Weather_conditions"].unique()                # Climate
# Out:
# array(['Normal', 'Raining', 'Raining and Windy', 'Cloudy', 'Other',
#        'Windy', 'Snow', 'Unknown', 'Fog or mist'], dtype=object)

# %%
data["Weather_conditions"].value_counts()
# Out:
# Weather_conditions
# Normal               10063
# Raining               1331
# Other                  296
# Unknown                292
# Cloudy                 125
# Windy                   98
# Snow                    61
# Raining and Windy       40
# Fog or mist             10
# Name: count, dtype: int64

# %%
data["Type_of_collision"].unique()       # Collision types
# Out:
# array(['Collision with roadside-parked vehicles',
#        'Vehicle with vehicle collision',
#        'Collision with roadside objects', 'Collision with animals',
#        'Other', 'Rollover', 'Fall from vehicles',
#        'Collision with pedestrians', 'With Train', 'Unknown', nan],
#       dtype=object)

# %%
data["Type_of_collision"].value_counts()
# Out:
# Type_of_collision
# Vehicle with vehicle collision             8774
# Collision with roadside objects            1786
# Collision with pedestrians                  896
# Rollover                                    397
# Collision with animals                      171
# Collision with roadside-parked vehicles      54
# Fall from vehicles                           34
# Other                                        26
# Unknown                                      14
# With Train                                    9
# Name: count, dtype: int64

# %%
data["Number_of_vehicles_involved"].unique()          # Involved Vehicles
# Out:
# array([2, 1, 3, 6, 4, 7])

# %%
data["Number_of_vehicles_involved"].value_counts()
# Out:
# Number_of_vehicles_involved
# 2    8340
# 1    1996
# 3    1568
# 4     363
# 6      42
# 7       7
# Name: count, dtype: int64

# %%
data["Number_of_casualties"].unique()                       # Casualties
# Out:
# array([2, 1, 3, 4, 6, 5, 8, 7])

# %%
data["Number_of_casualties"].value_counts()
# Out:
# Number_of_casualties
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: count, dtype: int64

# %%
data["Vehicle_movement"].unique()           # Vehicle_movement
# Out:
# array(['Going straight', 'U-Turn', 'Moving Backward', 'Turnover',
#        'Waiting to go', 'Getting off', 'Reversing', 'Unknown', 'Parked',
#        'Stopping', 'Overtaking', 'Other', 'Entering a junction', nan],
#       dtype=object)

# %%
data["Vehicle_movement"].value_counts()
# Out:
# Vehicle_movement
# Going straight         8158
# Moving Backward         985
# Other                   937
# Reversing               563
# Turnover                489
# Getting off             339
# Entering a junction     193
# Overtaking               96
# Unknown                  88
# Stopping                 61
# U-Turn                   50
# Waiting to go            39
# Parked                   10
# Name: count, dtype: int64

# %%
data["Casualty_class"].unique()          # Casualty class
# Out:
# array(['na', 'Driver or rider', 'Pedestrian', 'Passenger'], dtype=object)

# %%
data["Casualty_class"].value_counts()
# Out:
# Casualty_class
# Driver or rider    4944
# na                 4443
# Pedestrian         1649
# Passenger          1280
# Name: count, dtype: int64

# %%
data["Sex_of_casualty"].unique()               # Gender of casualty
# Out:
# array(['na', 'Male', 'Female'], dtype=object)

# %%
data["Sex_of_casualty"].value_counts()
# Out:
# Sex_of_casualty
# Male      5253
# na        4443
# Female    2620
# Name: count, dtype: int64

# %%
data["Age_band_of_casualty"].unique()         # Age groups of casualty
# Out:
# array(['na', '31-50', '18-30', 'Under 18', 'Over 51', '5'], dtype=object)

# %%
data["Age_band_of_casualty"].value_counts()
# Out:
# Age_band_of_casualty
# na          4443
# 18-30       3145
# 31-50       2455
# Under 18    1035
# Over 51      994
# 5            244
# Name: count, dtype: int64

# %%
data["Casualty_severity"].unique()        # Casualty severity
# Out:
# array(['na', '3', '2', '1'], dtype=object)

# %%
data["Casualty_severity"].value_counts()
# Out:
# Casualty_severity
# 3     7076
# na    4443
# 2      771
# 1       26
# Name: count, dtype: int64

# %%
data["Work_of_casuality"].unique()       # Work of casuality
# Out:
# array([nan, 'Driver', 'Other', 'Unemployed', 'Employee', 'Self-employed',
#        'Student', 'Unknown'], dtype=object)

# %%
data["Work_of_casuality"].value_counts()
# Out:
# Work_of_casuality
# Driver           5903
# Self-employed    2044
# Employee          553
# Other             463
# Student           103
# Unemployed         33
# Unknown            19
# Name: count, dtype: int64

# %%
data["Fitness_of_casuality"].unique()      # Fitness_of_casuality
# Out:
# array([nan, 'Normal', 'Deaf', 'Other', 'Blind', 'NormalNormal'],
#       dtype=object)

# %%
data["Fitness_of_casuality"].value_counts()
# Out:
# Fitness_of_casuality
# Normal          9608
# NormalNormal      19
# Deaf              18
# Other             18
# Blind             18
# Name: count, dtype: int64

# %%
data["Pedestrian_movement"].unique()
# Out:
# array(['Not a Pedestrian', "Crossing from driver's nearside",
#        'Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle',
#        'Unknown or other',
#        'Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)',
#        'Walking along in carriageway, back to traffic',
#        'Walking along in carriageway, facing traffic',
#        'In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing) - masked by parked or statioNot a Pedestrianry vehicle'],
#       dtype=object)

# %%
data["Pedestrian_movement"].value_counts()           # Pedestrian_movement
# Out:
# Pedestrian_movement
# Not a Pedestrian                                                                                                                         11390
# Crossing from nearside - masked by parked or statioNot a Pedestrianry vehicle                                                              337
# Unknown or other                                                                                                                           293
# Crossing from driver's nearside                                                                                                            140
# Crossing from offside - masked by  parked or statioNot a Pedestrianry vehicle                                                               72
# In carriageway, statioNot a Pedestrianry - not crossing  (standing or playing)                                                              46
# ...

# %%
data["Cause_of_accident"].unique()         # Cause_of_accident
# Out:
# array(['Moving Backward', 'Overtaking', 'Changing lane to the left',
#        'Changing lane to the right', 'Overloading', 'Other',
#        'No priority to vehicle', 'No priority to pedestrian',
#        'No distancing', 'Getting off the vehicle improperly',
#        'Improper parking', 'Overspeed', 'Driving carelessly',
#        'Driving at high speed', 'Driving to the left', 'Unknown',
#        'Overturning', 'Turnover', 'Driving under the influence of drugs',
#        'Drunk driving'], dtype=object)

# %%
data["Cause_of_accident"].value_counts()
# Out:
# Cause_of_accident
# No distancing                           2263
# Changing lane to the right              1808
# Changing lane to the left               1473
# Driving carelessly                      1402
# No priority to vehicle                  1207
# Moving Backward                         1137
# No priority to pedestrian                721
# Other                                    456
# Overtaking                               430
# Driving under the influence of drugs     340
# Driving to the left                      284
# Getting off the vehicle improperly       197
# Driving at high speed                    174
# Overturning                              149
# Turnover                                  78
# Overspeed                                 61
# Overloading                               59
# Drunk driving                             27
# Improper parking                          25
# Unknown                                   25
# Name: count, dtype: int64

# %%
data["Accident_severity"].unique()        # Accident_severity
# Out:
# array(['Slight Injury', 'Serious Injury', 'Fatal injury'], dtype=object)

# %%
data["Accident_severity"].value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %% [markdown]
# #### Understanding about data like data types and null values available

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
# ...

# %% [markdown]
# #### Shape of dataset

# %%
data.shape
# Out:
# (12316, 32)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)
#
# #### Generate descriptive statistics of the data

# %%
data.describe(include="object")
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      12316       12316              12316         12316
# unique      1074           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq         120        2041               4271         11437
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                11575                   11737              11487
# unique                   7                       4                  7
# top     Junior high school                Employee             5-10yr
# freq                  7619                    9627               3363
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# count            11366            11834                    8388  ...
# unique              17                4                       6  ...
# top         Automobile            Owner                 Unknown  ...
# ...

# %%
data.describe()
# Out:
#        Number_of_vehicles_involved  Number_of_casualties
# count                 12316.000000          12316.000000
# mean                      2.040679              1.548149
# std                       0.688790              1.007179
# min                       1.000000              1.000000
# 25%                       2.000000              1.000000
# 50%                       2.000000              1.000000
# 75%                       2.000000              2.000000
# max                       7.000000              8.000000

# %%
# Distribution of Accident_severity

data["Accident_severity"].value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %% [markdown]
# ####  Data Visualized With Count Plot

# %%
# Plotting the final class

sns.countplot(x="Accident_severity", data=data, hue ="Accident_severity")
plt.title("Distribution of Accident Severity")
plt.xlabel("Accident Severity")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ### Handaling Missing Values

# %%
data.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %% [markdown]
# #### Drop columns which has more than 2500 missing values and Time columns are removed

# %%
data.drop(columns=["Service_year_of_vehicle","Defect_of_vehicle","Work_of_casuality","Fitness_of_casuality","Time"],inplace=True)
data.head()
# Out:
#   Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      Monday              18-30          Male   Above high school
# 1      Monday              31-50          Male  Junior high school
# 2      Monday              18-30          Male  Junior high school
# 3      Sunday              18-30          Male  Junior high school
# 4      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured   Lanes_or_Medians  ...  \
# 0            Owner     Residential areas                NaN  ...
# ...

# %% [markdown]
# ### Numerical data stored in Numerical Variable

# %%
Numerical = data.select_dtypes(exclude="object")
Numerical.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties
# 0                            2                     2
# 1                            2                     2
# 2                            2                     2
# 3                            2                     2
# 4                            2                     2

# %% [markdown]
# ### Categorical data stored in Categorical Variable

# %%
Categorical  = data.select_dtypes(include="object")
Categorical.head()
# Out:
#   Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0      Monday              18-30          Male   Above high school
# 1      Monday              31-50          Male  Junior high school
# 2      Monday              18-30          Male  Junior high school
# 3      Sunday              18-30          Male  Junior high school
# 4      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Area_accident_occured   Lanes_or_Medians  ...  \
# 0            Owner     Residential areas                NaN  ...
# ...

# %%
Categorical.columns
# Out:
# Index(['Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision', 'Vehicle_movement',
#        'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty',
#        'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity'],
#       dtype='object')

# %% [markdown]
# ### Categorical values we can replace with mode

# %%
for i in Categorical:
    data[i].fillna(data[i].mode()[0],inplace = True)

# %%
data.isnull().sum()
# Out:
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %% [markdown]
# ### Data Visualized with Scatterplot
#
# * Plotting relationship between Number_of_casualties and Number_of_vehicles_involved

# %%
sns.scatterplot(x = "Number_of_casualties", y = "Number_of_vehicles_involved" ,data = data , hue = "Accident_severity")
plt.show()

# %% [markdown]
# * There is no visiable correlation between Number_of_casualties and Number_of_vehicles_involved

# %%
# Join plot

sns.jointplot(x="Number_of_casualties", y = "Number_of_vehicles_involved", data = data, hue = "Accident_severity")
plt.show()

# %% [markdown]
# ###### Checking the Correlation between Numerical Columns

# %%
Numerical.corr()
# Out:
#                              Number_of_vehicles_involved  Number_of_casualties
# Number_of_vehicles_involved                     1.000000              0.213427
# Number_of_casualties                            0.213427              1.000000

# %%
sns.heatmap(Numerical.corr())
plt.show()

# %% [markdown]
# #### Numerical Data Visualized with Histogram

# %%
plt.rcParams['figure.figsize']=(18,8)

plt.subplot(1,2,1)
sns.histplot(data["Number_of_vehicles_involved"],kde = True)
plt.title("Involved Vehicals")

plt.subplot(1,2,2)
sns.histplot(data["Number_of_casualties"], kde =True)
plt.title("Number of Casualties")

plt.show()

# %%
Categorical.columns
# Out:
# Index(['Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Area_accident_occured',
#        'Lanes_or_Medians', 'Road_allignment', 'Types_of_Junction',
#        'Road_surface_type', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision', 'Vehicle_movement',
#        'Casualty_class', 'Sex_of_casualty', 'Age_band_of_casualty',
#        'Casualty_severity', 'Pedestrian_movement', 'Cause_of_accident',
#        'Accident_severity'],
#       dtype='object')

# %%
# Remove 'Pedestrian_movement' from the list

Categorical = [col for col in Categorical if col != 'Pedestrian_movement']

# Calculate the number of rows and columns for subplots
num_plots = len(Categorical)
num_rows = (num_plots + 1) // 2  # Round up if number of plots is odd
num_cols = 2  # Number of columns in the subplot grid


# Create a figure with a specific size based on the number of subplots
plt.figure(figsize=(12, num_rows * 5))  # Adjust height dynamically


# Loop through each column and create a countplot
plotnumber = 1
for col in Categorical:
    plt.subplot(num_rows, num_cols, plotnumber)  # Create subplot
    sns.countplot(data=data, y=col, palette='muted')  # Create countplot with the categorical column
    plt.title(col.title(), fontsize=14)
    plt.xlabel('')
    plt.ylabel('Count', fontsize=12)
    plt.xticks(fontsize=10)
    plt.yticks(fontsize=12)
    plotnumber += 1  # Increment plotnumber after each plot

# Adjust layout to prevent overlapping subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Handling Categorical Values

# %%
data.dtypes
# Out:
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# Age_band_of_casualty           object
# Casualty_severity              object
# Pedestrian_movement            object
# ...

# %% [markdown]
# #### Since there are so many Categorical Values, we need to use feture selection, we need to use LabelEncoder before applying chi square analysis

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
#creating a new data frame from performing the chi2 analysis
df1=pd.DataFrame()

#adding all the categorical columns except the output to new data frame
for i in Categorical:
    if i!= 'Accident_severity':
        df1[i]=le.fit_transform(data[i])

# %%
df1.head()
# Out:
#    Day_of_week  Age_band_of_driver  Sex_of_driver  Educational_level  \
# 0            1                   0              1                  0
# 1            1                   1              1                  4
# 2            1                   0              1                  4
# 3            3                   0              1                  4
# 4            3                   0              1                  4
#
#    Vehicle_driver_relation  Driving_experience  Type_of_vehicle  \
# 0                        0                   0                0
# 1                        0                   3               11
# 2                        0                   0                5
# 3                        0                   2               11
# 4                        0                   1                0
#
#    Owner_of_vehicle  Area_accident_occured  Lanes_or_Medians  ...  \
# 0                 3                      9                 2  ...
# ...

# %%
#confirming the data type
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Day_of_week              12316 non-null  int64
#  1   Age_band_of_driver       12316 non-null  int64
#  2   Sex_of_driver            12316 non-null  int64
#  3   Educational_level        12316 non-null  int64
#  4   Vehicle_driver_relation  12316 non-null  int64
#  5   Driving_experience       12316 non-null  int64
#  6   Type_of_vehicle          12316 non-null  int64
#  7   Owner_of_vehicle         12316 non-null  int64
#  8   Area_accident_occured    12316 non-null  int64
#  9   Lanes_or_Medians         12316 non-null  int64
#  10  Road_allignment          12316 non-null  int64
#  11  Types_of_Junction        12316 non-null  int64
#  12  Road_surface_type        12316 non-null  int64
#  13  Road_surface_conditions  12316 non-null  int64
# ...

# %% [markdown]
# #### Cheking Correlation

# %%
plt.figure(figsize=(22,17))
sns.set(font_scale=1)
sns.heatmap(df1.corr(), annot=True)
# Out:
# <Axes: >

# %%
df1.corr()
# Out:
#                          Day_of_week  Age_band_of_driver  Sex_of_driver  \
# Day_of_week                 1.000000            0.019993       0.009986
# Age_band_of_driver          0.019993            1.000000      -0.351878
# Sex_of_driver               0.009986           -0.351878       1.000000
# Educational_level          -0.004517            0.013613       0.004967
# Vehicle_driver_relation     0.003303           -0.005841       0.011035
# Driving_experience         -0.010062           -0.013407       0.009855
# Type_of_vehicle            -0.002417            0.004830      -0.003757
# Owner_of_vehicle            0.001417            0.005405      -0.009489
# Area_accident_occured       0.003281            0.011472      -0.000274
# Lanes_or_Medians           -0.009320            0.008176      -0.012529
# Road_allignment            -0.008505            0.000486      -0.002238
# Types_of_Junction          -0.026669           -0.028025       0.004920
# ...

# %%
#import chi2 test
from sklearn.feature_selection import chi2
f_p_values=chi2(df1,data['Accident_severity'])

# %%
#f_p_values will return Fscore and pvalues
f_p_values
# Out:
# (array([ 0.15822071,  8.91539214,  0.1431894 ,  0.17458477,  5.34534549,
#          4.49967858,  1.07767124,  1.10426215,  3.61654037,  3.28161464,
#          0.1319306 ,  3.08648691,  6.99480557,  0.61510308, 16.08282359,
#          1.14934538, 10.09632283,  2.20071197,  3.2168602 ,  0.12594479,
#         13.77841337,  0.20273788,  3.19366551]),
#  array([9.23937958e-01, 1.15890328e-02, 9.30908116e-01, 9.16409114e-01,
#         6.90673790e-02, 1.05416165e-01, 5.83427189e-01, 5.75721597e-01,
#         1.63937473e-01, 1.93823502e-01, 9.36163348e-01, 2.13686893e-01,
#         3.02759144e-02, 7.35244973e-01, 3.21854237e-04, 5.62889079e-01,
#         6.42112839e-03, 3.32752607e-01, 2.00201664e-01, 9.38969394e-01,
#         1.01872169e-03, 9.03599597e-01, 2.02536988e-01]))

# %%
#for better understanding and ease of access adding them to a new dataframe

f_p_values1=pd.DataFrame({'features':df1.columns, 'Fscore': f_p_values[0], 'Pvalues':f_p_values[1]})
f_p_values1
# Out:
#                    features     Fscore   Pvalues
# 0               Day_of_week   0.158221  0.923938
# 1        Age_band_of_driver   8.915392  0.011589
# 2             Sex_of_driver   0.143189  0.930908
# 3         Educational_level   0.174585  0.916409
# 4   Vehicle_driver_relation   5.345345  0.069067
# 5        Driving_experience   4.499679  0.105416
# 6           Type_of_vehicle   1.077671  0.583427
# 7          Owner_of_vehicle   1.104262  0.575722
# 8     Area_accident_occured   3.616540  0.163937
# 9          Lanes_or_Medians   3.281615  0.193824
# 10          Road_allignment   0.131931  0.936163
# 11        Types_of_Junction   3.086487  0.213687
# 12        Road_surface_type   6.994806  0.030276
# 13  Road_surface_conditions   0.615103  0.735245
# 14         Light_conditions  16.082824  0.000322
# 15       Weather_conditions   1.149345  0.562889
# 16        Type_of_collision  10.096323  0.006421
# 17         Vehicle_movement   2.200712  0.332753
# ...

# %%
#since we want lower Pvalues we are sorting the features
f_p_values1.sort_values(by='Pvalues',ascending=True)
# Out:
#                    features     Fscore   Pvalues
# 14         Light_conditions  16.082824  0.000322
# 20     Age_band_of_casualty  13.778413  0.001019
# 16        Type_of_collision  10.096323  0.006421
# 1        Age_band_of_driver   8.915392  0.011589
# 12        Road_surface_type   6.994806  0.030276
# 4   Vehicle_driver_relation   5.345345  0.069067
# 5        Driving_experience   4.499679  0.105416
# 8     Area_accident_occured   3.616540  0.163937
# 9          Lanes_or_Medians   3.281615  0.193824
# 18           Casualty_class   3.216860  0.200202
# 22        Cause_of_accident   3.193666  0.202537
# 11        Types_of_Junction   3.086487  0.213687
# 17         Vehicle_movement   2.200712  0.332753
# 15       Weather_conditions   1.149345  0.562889
# 7          Owner_of_vehicle   1.104262  0.575722
# 6           Type_of_vehicle   1.077671  0.583427
# 13  Road_surface_conditions   0.615103  0.735245
# 21        Casualty_severity   0.202738  0.903600
# ...

# %% [markdown]
# we need higher Fscore and lower the Pvalues, so by evaluating, we can remove Owner_of_vehicle, Type_of_vehicle, Road_surface_conditions,
#
#
# Pedestrian_movement,Casualty_severity,Educational_level,Day_of_week,Sex_of_driver,Road_allignment, Sex_of_casualty

# %%
#after evaluating we are removing lesser important columns and storing to a new data frame
df2=data.drop(['Owner_of_vehicle', 'Type_of_vehicle', 'Road_surface_conditions', 'Pedestrian_movement',
         'Casualty_severity','Educational_level','Day_of_week','Sex_of_driver','Road_allignment',
         'Sex_of_casualty'],axis=1)
df2.head()
# Out:
#   Age_band_of_driver Vehicle_driver_relation Driving_experience  \
# 0              18-30                Employee              1-2yr
# 1              31-50                Employee         Above 10yr
# 2              18-30                Employee              1-2yr
# 3              18-30                Employee             5-10yr
# 4              18-30                Employee              2-5yr
#
#   Area_accident_occured                                  Lanes_or_Medians  \
# 0     Residential areas  Two-way (divided with broken lines road marking)
# 1          Office areas                                 Undivided Two way
# 2    Recreational areas                                             other
# 3          Office areas                                             other
# 4      Industrial areas                                             other
#
#   Types_of_Junction Road_surface_type       Light_conditions  \
# 0       No junction     Asphalt roads               Daylight
# ...

# %%
df2.shape
# Out:
# (12316, 17)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Age_band_of_driver           12316 non-null  object
#  1   Vehicle_driver_relation      12316 non-null  object
#  2   Driving_experience           12316 non-null  object
#  3   Area_accident_occured        12316 non-null  object
#  4   Lanes_or_Medians             12316 non-null  object
#  5   Types_of_Junction            12316 non-null  object
#  6   Road_surface_type            12316 non-null  object
#  7   Light_conditions             12316 non-null  object
#  8   Weather_conditions           12316 non-null  object
#  9   Type_of_collision            12316 non-null  object
#  10  Number_of_vehicles_involved  12316 non-null  int64
#  11  Number_of_casualties         12316 non-null  int64
#  12  Vehicle_movement             12316 non-null  object
# ...

# %%
#to check distinct values in each categorical columns we are storing them to a new variable
categorical_new=[i for i in df2.columns if df2[i].dtype=='O']
print(categorical_new)
# Out:
# ['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident', 'Accident_severity']

# %%
for i in categorical_new:
    print(df2[i].value_counts())
# Out:
# Age_band_of_driver
# 18-30       4271
# 31-50       4087
# Over 51     1585
# Unknown     1548
# Under 18     825
# Name: count, dtype: int64
# Vehicle_driver_relation
# Employee    10206
# Owner        1973
# Other         123
# Unknown        14
# Name: count, dtype: int64
# Driving_experience
# 5-10yr        4192
# 2-5yr         2613
# Above 10yr    2262
# 1-2yr         1756
# Below 1yr     1342
# No Licence     118
# unknown         33
# Name: count, dtype: int64
# Area_accident_occured
# Other                              4058
# Office areas                       3451
# Residential areas                  2060
#  Church areas                      1060
#  Industrial areas                   456
# School areas                        415
#   Recreational areas                327
#  Outside rural areas                218
#  Hospital areas                     121
#   Market areas                       63
# Rural village areas                  44
# ...

# %%
#get_dummies
dummy=pd.get_dummies(df2[['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience',
                          'Area_accident_occured', 'Lanes_or_Medians', 'Types_of_Junction', 'Road_surface_type', 
                          'Light_conditions', 'Weather_conditions', 'Type_of_collision', 'Vehicle_movement', 
                          'Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident']],drop_first=True)
dummy.head()
# Out:
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                     False                       False
# 1                      True                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# 4                        False                       False
#
#    Vehicle_driver_relation_Other  Vehicle_driver_relation_Owner  \
# 0                          False                          False
# 1                          False                          False
# 2                          False                          False
# ...

# %%
#concatinate dummy and old data frame
df3=pd.concat([df2,dummy],axis=1)
df3.head()
# Out:
#   Age_band_of_driver Vehicle_driver_relation Driving_experience  \
# 0              18-30                Employee              1-2yr
# 1              31-50                Employee         Above 10yr
# 2              18-30                Employee              1-2yr
# 3              18-30                Employee             5-10yr
# 4              18-30                Employee              2-5yr
#
#   Area_accident_occured                                  Lanes_or_Medians  \
# 0     Residential areas  Two-way (divided with broken lines road marking)
# 1          Office areas                                 Undivided Two way
# 2    Recreational areas                                             other
# 3          Office areas                                             other
# 4      Industrial areas                                             other
#
#   Types_of_Junction Road_surface_type       Light_conditions  \
# 0       No junction     Asphalt roads               Daylight
# ...

# %%
#dropping dummied columns
df3.drop(['Age_band_of_driver', 'Vehicle_driver_relation', 'Driving_experience', 'Area_accident_occured', 'Lanes_or_Medians',
          'Types_of_Junction', 'Road_surface_type', 'Light_conditions', 'Weather_conditions', 'Type_of_collision',
          'Vehicle_movement','Casualty_class', 'Age_band_of_casualty', 'Cause_of_accident'],axis=1,inplace=True)
df3.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties Accident_severity  \
# 0                            2                     2     Slight Injury
# 1                            2                     2     Slight Injury
# 2                            2                     2    Serious Injury
# 3                            2                     2     Slight Injury
# 4                            2                     2     Slight Injury
#
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                     False                       False
# 1                      True                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 0                        False                       False
# 1                        False                       False
# ...

# %% [markdown]
# ### Seperating Independent and Dependent

# %%
x=df3.drop(['Accident_severity'],axis=1)
x.shape
# Out:
# (12316, 104)

# %%
x.head()
# Out:
#    Number_of_vehicles_involved  Number_of_casualties  \
# 0                            2                     2
# 1                            2                     2
# 2                            2                     2
# 3                            2                     2
# 4                            2                     2
#
#    Age_band_of_driver_31-50  Age_band_of_driver_Over 51  \
# 0                     False                       False
# 1                      True                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    Age_band_of_driver_Under 18  Age_band_of_driver_Unknown  \
# 0                        False                       False
# 1                        False                       False
# 2                        False                       False
# 3                        False                       False
# ...

# %%
y = df3.iloc[:,2]
y.head()
# Out:
# 0     Slight Injury
# 1     Slight Injury
# 2    Serious Injury
# 3     Slight Injury
# 4     Slight Injury
# Name: Accident_severity, dtype: object

# %%
#checking the count of each item in the output column
y.value_counts()
# Out:
# Accident_severity
# Slight Injury     10415
# Serious Injury     1743
# Fatal injury        158
# Name: count, dtype: int64

# %%
#plotting count plot using seaborn
sns.countplot(x = y, palette='muted')
# Out:
# <Axes: xlabel='Accident_severity', ylabel='count'>

# %% [markdown]
# ### Oversampling

# %%
#importing SMOTE 
from imblearn.over_sampling import SMOTE
oversample=SMOTE()
xo,yo=oversample.fit_resample(x,y)

# %%
#checking the oversampling output
y1=pd.DataFrame(yo)
y1.value_counts()
# Out:
# Accident_severity
# Fatal injury         10415
# Serious Injury       10415
# Slight Injury        10415
# Name: count, dtype: int64

# %%
sns.countplot(x = yo, palette='muted')
plt.show()

# %% [markdown]
# ### Splitting the data

# %%
#converting data to training data and testing data

from sklearn.model_selection import train_test_split

#splitting 70% of the data to training data and 30% of data to testing data

x_train,x_test,y_train,y_test=train_test_split(xo,yo,test_size=0.30,random_state=42)

# %%
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (21871, 104) (9374, 104) (21871,) (9374,)

# %% [markdown]
# ### KNN Model Creation
#
#
# ### Prediction

# %%
#KNN model alg
from sklearn.neighbors import KNeighborsClassifier
model_KNN=KNeighborsClassifier(n_neighbors=5)
model_KNN.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model_KNN.predict(x_test)

y_pred
# Out:
# array(['Serious Injury', 'Serious Injury', 'Slight Injury', ...,
#        'Fatal injury', 'Serious Injury', 'Serious Injury'], dtype=object)

# %% [markdown]
# ### Checking Accuracy, Classification Report, Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,ConfusionMatrixDisplay

# %% [markdown]
# ### Classification Report

# %%
report_KNN=classification_report(y_test,y_pred)
print(report_KNN)
# Out:
#                 precision    recall  f1-score   support
#
#   Fatal injury       0.79      1.00      0.88      3126
# Serious Injury       0.64      0.91      0.75      3144
#  Slight Injury       0.96      0.30      0.46      3104
#
#       accuracy                           0.74      9374
#      macro avg       0.80      0.74      0.70      9374
#   weighted avg       0.80      0.74      0.70      9374

# %% [markdown]
# ### Accuracy Score

# %%
accuracy_KNN=accuracy_score(y_test,y_pred)
print(accuracy_KNN)
# Out:
# 0.7387454661830595

# %% [markdown]
# ### Confusion Matrix

# %%
matrix_KNN=confusion_matrix(y_test,y_pred)
print(matrix_KNN,'\n')
print(ConfusionMatrixDisplay.from_predictions(y_test,y_pred))
# Out:
# [[3125    1    0]
#  [ 248 2858   38]
#  [ 572 1590  942]]
#
# ...
